# %%
import numpy as np
import pandas as pd
import scipy.stats as ss
import seaborn as sns
import requests
from urllib.parse import urlencode

# %% [markdown]
# ### Function Description
#
# **Retention rate** shows how many clients return to the application for a certain period after installation.
#
# To use the function, you need to set the start date and the end date of the period.
#
# **Requirements**
# 1. The start date must be greater than the end date of the period and is indicated in quotation marks.
# 2. The function is configured for the number of days, if you need to count by months, then you need to change the date format and bring it to the beginning of the month.
#
# **Method of operation**
# 1. Accepts two entry dates (the beginning and the end of the period).
# 2. Reads two links (registration dates and event dates), converts the date format, makes a filter
# 3. Prepares both tables for merging:
# * ***Registration table***: For each registration record, a list of all dates from the beginning to the end of the period is created
# * ***Table with events***: mark each row by symbol (1) so that when combining it was clear on what date the action was (this approach was chosen so that not only the date of the event, but also any chosen action could be selected for the target action, for example, the date where the price is indicated, and put 1 next to the columns with the price, then counting retention on them)
# 4. Tables are combined by columns uid and date of events (we get a table where for each user there is a registration date, all possible dates from the list, the units affixed to the dates where the action was)
# 5. We calculate retention through a pivot table, where for values we take the average of the columns with bullits (there was an action and there was no action), or we take the amount of the column with actions and count the percentage from the first day, where 100% of users)

# %%
# read data from yandex disk
def ya_disk_download(url):
    base_url = 'https://cloud-api.yandex.net/v1/disk/public/resources/download?'
    
    final_url = base_url + urlencode(dict(public_key=url)) 
    response = requests.get(final_url) 
    download_url = response.json()['href'] 
 
    download_response = requests.get(download_url) 
    df = pd.read_csv(download_url, sep=';')
    return df

# %%
registration_url = 'https://disk.yandex.ru/d/PczS9KCTyxCMvw'
actions_url = 'https://disk.yandex.ru/d/noL8tO5a2q-_yg'

# %%
registration = ya_disk_download(registration_url)
actions = ya_disk_download(actions_url)

# %%
# table with reg date and user id
registration.head()
# Out:
#       reg_ts  uid
# 0 1998-11-18    1
# 1 1999-07-22    2
# 2 2000-01-13    3
# 3 2000-05-28    4
# 4 2000-09-16    5

# %%
# table with action date nd user id
actions.head()
# Out:
#         days  uid  action
# 0 1998-11-18    1       1
# 1 1999-07-22    2       1
# 2 1999-07-25    2       1
# 3 1999-07-31    2       1
# 4 1999-08-05    2       1

# %%
def retention(reg_data, auth_data, a, b):
    '''
    Retention calculation function for the specified period
    Input data:
        reg_data - dataframe with the date of user registration
        auth_data - dataframe with targeted user actions
        a - start of the period
        b - end of the period

    Output data:
        column with total base in group
        retention - table with retention by day
    '''
    reg_data['reg_ts'] = pd.to_datetime(reg_data['reg_ts'], unit='s')
    reg_data['reg_ts'] = pd.to_datetime(reg_data['reg_ts'].dt.date, format='%Y-%m-%d')
    
    auth_data['auth_ts'] = pd.to_datetime(auth_data['auth_ts'], unit='s')
    auth_data['auth_ts'] = pd.to_datetime(auth_data['auth_ts'].dt.date, format='%Y-%m-%d')
    auth_data['action'] = 1  
    auth_data.columns = ['days', 'uid', 'action']
    
    # filter for dates
    reg_data = reg_data.query('reg_ts >= @a and reg_ts <= @b')
    auth_data = auth_data.query('days >= @a and days <= @b')
    
    # for each user make a list of all dates in the periodе
    days = pd.DataFrame(pd.date_range(a, b))
    days.columns = ['days']
    
    reg_data['key'] = 1
    days['key'] = 1

    reg_data = reg_data.merge(days, how='outer', on='key')
    reg_data = reg_data.query('days >= reg_ts')
    
    df = reg_data.merge(auth_data, on=['uid', 'days'], how='left')
    df['activity'] = (df['action'] > 0) * 1
    
    # creating a column with cohorts (number of days after registration) and retention
    df['lifetime'] = ((df['days'] - df['reg_ts']) / np.timedelta64(1, 'D')).round().astype(int)
    
    retention = df.pivot_table(index='reg_ts', columns='lifetime', values='activity', aggfunc='sum')
    cohort = retention.iloc[:, 0]  # creating a separate column with the number of people in the cohort
    retention = retention.divide(cohort, axis=0)
    retention[0] = cohort.astype('int32')
    
    # plotting
    retention.index = retention.index.astype('string').str.replace(' .*', '')
    cm = sns.light_palette("#a275ac", as_cmap=True)
    df_style = (
        retention
        .style
        .set_caption('Cohorts: User Retention')
        .background_gradient(cmap=cm, subset=retention.select_dtypes(float).columns)   
        .highlight_null('white')
        .format("{:.0%}", na_rep="", subset=retention.select_dtypes(float).columns))
    return (df_style)

# %%
retention(registration, actions, "2016-12-07", "2016-12-16")
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <style  type="text/css" >
# #T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col1{
#             background-color:  #c9b2ce;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col2{
#             background-color:  #d3c1d7;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col3{
#             background-color:  #ad85b5;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col2,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col1{
#             background-color:  #a275ac;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col6{
#             background-color:  #d8cadc;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col7{
#             background-color:  #d6c7da;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col2,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col1{
#             background-color:  #f1f0f1;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col1,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col1{
#             background-color:  #e4dce6;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col2{
#             background-color:  #b693bd;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col3{
#             background-color:  #cfbbd3;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col4{
#             background-color:  #d2c0d6;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col5{
#             background-color:  #b695be;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row1_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col9,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col9{
#             background-color:  #f1f0f1;
#             color:  #000000;
#             background-color:  white;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col1{
#             background-color:  #ae88b7;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col2{
#             background-color:  #e7e0e8;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col6{
#             background-color:  #ccb6d1;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row2_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col2,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row8_col8,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col1,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col2,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col4,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col6,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col7,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row9_col8{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  white;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col1{
#             background-color:  #d7c7da;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col2,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col2{
#             background-color:  #c0a4c6;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row3_col5{
#             background-color:  #b796be;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col1,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col1{
#             background-color:  #af89b7;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row4_col5,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row7_col2{
#             background-color:  #cab3cf;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col3,#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row6_col3{
#             background-color:  #d0bcd4;
#             color:  #000000;
#         }#T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row5_col4{
#             background-color:  #e2d9e4;
#             color:  #000000;
#         }</style><table id="T_f2ccf794_abdc_11ed_bdbb_96000040dfb6" ><caption>Cohorts: User Retention</caption><thead>    <tr>        <th class="index_name level0" >lifetime</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <th class="col_heading level0 col8" >8</th>        <th class="col_heading level0 col9" >9</th>    </tr>    <tr>        <th class="index_name level0" >reg_ts</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2ccf794_abdc_11ed_bdbb_96000040dfb6level0_row0" class="row_heading level0 row0" >2016-12-07</th>
#                         <td id="T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col0" class="data row0 col0" >168</td>
#                         <td id="T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col1" class="data row0 col1" >2%</td>
#                         <td id="T_f2ccf794_abdc_11ed_bdbb_96000040dfb6row0_col2" class="data row0 col2" >4%</td>

# %%
print(retention.__doc__)
# Out:
#     Retention calculation function for the specified period
#     Input data:
#         reg_data - dataframe with the date of user registration
#         auth_data - dataframe with targeted user actions
#         a - start of the period
#         b - end of the period
#
#     Output data:
#         column with total base in group
#         retention - table with retention by day
